# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
#change working directory
os.chdir("C:\\Users\\Marta\\Documents\\GitHub\\pythonic-learning-machine\\data_sets\\06_formatted\\c_ionosphere\\")

# %%
#testing value 
testing_value = pd.read_csv("testing_value.csv")
testing_value = testing_value[['SLM (Ensemble)', 'SLM (Ensemble) + RST', 'SLM (Ensemble) + RWT', 'SLM (Ensemble-Bagging)', 
                               'SLM (Ensemble-Bagging) + RST', 'SLM (Ensemble-Bagging) + RWT', 'SLM (Ensemble-RIW)',
                                'SLM (Ensemble-Boosting)', 'SLM (OLS)', 'SLM (OLS) + RST', 'SLM (OLS) + RWT']]
testing_value.head()
# Out:
#    SLM (Ensemble)  SLM (Ensemble) + RST  SLM (Ensemble) + RWT  \
# 0        0.290845              0.303740              0.274802
# 1        0.294252              0.305735              0.308493
# 2        0.312093              0.309520              0.303007
# 3        0.302079              0.307326              0.310762
# 4        0.312147              0.322789              0.321479
#
#    SLM (Ensemble-Bagging)  SLM (Ensemble-Bagging) + RST  \
# 0                0.264941                      0.276499
# 1                0.285161                      0.338903
# 2                0.308143                      0.302124
# 3                0.303463                      0.289330
# 4                0.321055                      0.341995
#
#    SLM (Ensemble-Bagging) + RWT  SLM (Ensemble-RIW)  SLM (Ensemble-Boosting)  \
# 0                      0.281159            0.302095                 0.271520
# 1                      0.297106            0.315852                 0.315311
# 2                      0.322022            0.352532                 0.316077
# 3                      0.311483            0.462863                 0.342482
# 4                      0.329166            0.352295                 0.349259
#
#    SLM (OLS)  SLM (OLS) + RST  SLM (OLS) + RWT
# 0   0.266063         0.360069         0.401511
# 1   0.433536         0.332275         0.358017
# 2   0.389878         0.269896         0.373590
# 3   0.406557         0.421731         0.352047
# 4   0.312964         0.319273         0.331045

# %%
cmap = sns.choose_cubehelix_palette(as_cmap=True)
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %%
fig, ax = plt.subplots()
boxplot = sns.boxplot(data=testing_value, palette="PuBuGn_d")
boxplot.set(xlabel='Algorithms', ylabel='RMSE')
sns.set_context("paper", font_scale=2)
sns.set_style("white")
sns.despine(left=True)
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
#training value 
training_value = pd.read_csv("training_value.csv")
training_value = training_value[['SLM (Ensemble)', 'SLM (Ensemble) + RST', 'SLM (Ensemble) + RWT', 'SLM (Ensemble-Bagging)', 
                               'SLM (Ensemble-Bagging) + RST', 'SLM (Ensemble-Bagging) + RWT', 'SLM (Ensemble-RIW)',
                                'SLM (Ensemble-Boosting)', 'SLM (OLS)', 'SLM (OLS) + RST', 'SLM (OLS) + RWT']]
training_value.head()
# Out:
#    SLM (Ensemble)  SLM (Ensemble) + RST  SLM (Ensemble) + RWT  \
# 0        0.260575              0.286963              0.248958
# 1        0.209724              0.222031              0.229526
# 2        0.230860              0.207741              0.219255
# 3        0.240349              0.250374              0.243157
# 4        0.208738              0.243221              0.234986
#
#    SLM (Ensemble-Bagging)  SLM (Ensemble-Bagging) + RST  \
# 0                0.240245                      0.244823
# 1                0.205351                      0.288894
# 2                0.205522                      0.209040
# 3                0.243388                      0.210266
# 4                0.228746                      0.259603
#
#    SLM (Ensemble-Bagging) + RWT  SLM (Ensemble-RIW)  SLM (Ensemble-Boosting)  \
# 0                      0.276512            0.299474                 0.278291
# 1                      0.203314            0.257160                 0.238292
# 2                      0.219332            0.302139                 0.225845
# 3                      0.258926            0.473969                 0.307444
# 4                      0.241035            0.280369                 0.274239
#
#    SLM (OLS)  SLM (OLS) + RST  SLM (OLS) + RWT
# 0   0.181351         0.340978         0.384044
# 1   0.376508         0.115664         0.341883
# 2   0.078086         0.079725         0.291966
# 3   0.276788         0.321941         0.221438
# 4   0.080514         0.110005         0.312239

# %%
fig, ax = plt.subplots()
boxplot = sns.boxplot(data=training_value, palette="PuBuGn_d")
boxplot.set(xlabel='Algorithms', ylabel='RMSE')
sns.set_context("paper", font_scale=2)
sns.set_style("white")
sns.despine(left=True)
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
fig.set_size_inches(18.5, 10.5)
plt.show()
