# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import os

# %%
#change working directory
os.chdir("C:\\Users\\Marta\\Documents\\GitHub\\pythonic-learning-machine\\data_sets\\06_formatted\\c_diabetes\\")

# %%
#testing value 
testing_value = pd.read_csv("testing_value.csv")
testing_value = testing_value[['SLM (Ensemble)', 'SLM (Ensemble) + RST', 'SLM (Ensemble) + RWT', 'SLM (Ensemble-Bagging)', 
                               'SLM (Ensemble-Bagging) + RST', 'SLM (Ensemble-Bagging) + RWT', 'SLM (Ensemble-RIW)',
                               'SLM (Ensemble-Boosting)', 'SLM (OLS)', 'SLM (OLS) + RST', 'SLM (OLS) + RWT']]
testing_value.head(10)
# Out:
#    SLM (Ensemble)  SLM (Ensemble) + RST  SLM (Ensemble) + RWT  \
# 0        0.417319              0.418119              0.422022
# 1        0.425017              0.424339              0.425051
# 2        0.375349              0.377424              0.377627
# 3        0.394508              0.393756              0.394176
# 4        0.384473              0.399881              0.391652
# 5        0.416257              0.424047              0.416075
# 6        0.413333              0.410952              0.417468
# 7        0.421513              0.417436              0.420261
# 8        0.417219              0.417452              0.423882
# 9        0.406496              0.407987              0.408673
#
#    SLM (Ensemble-Bagging)  SLM (Ensemble-Bagging) + RST  \
# 0                0.419008                      0.414497
# 1                0.421317                      0.426152
# 2                0.376547                      0.374230
# 3                0.393337                      0.407124
# 4                0.388495                      0.386248
# 5                0.411398                      0.410377
# 6                0.412890                      0.416625
# 7                0.421305                      0.418930
# 8                0.415903                      0.424742
# 9                0.407152                      0.405583
#
#    SLM (Ensemble-Bagging) + RWT  SLM (Ensemble-RIW)  SLM (Ensemble-Boosting)  \
# 0                      0.420050            0.418745                 0.417908
# 1                      0.423374            0.425029                 0.424567
# 2                      0.378448            0.378399                 0.369528
# 3                      0.398196            0.391190                 0.379638
# 4                      0.387614            0.393064                 0.383387
# 5                      0.417209            0.417155                 0.410671
# 6                      0.416418            0.413909                 0.408864
# 7                      0.418162            0.418056                 0.415947
# 8                      0.423684            0.424635                 0.428140
# 9                      0.407548            0.407502                 0.415409
#
#    SLM (OLS)  SLM (OLS) + RST  SLM (OLS) + RWT
# 0   0.417389         0.414840         0.431168
# 1   0.426624         0.429944         0.432325
# 2   0.378097         0.385007         0.381153
# 3   0.390704         0.400554         0.394717
# 4   0.393906         0.401552         0.384114
# 5   0.423831         0.432060         0.436680
# 6   0.425232         0.414917         0.410606
# 7   0.412045         0.429613         0.428667
# 8   0.430287         0.424268         0.445155
# 9   0.415800         0.426606         0.424855

# %%
fig, ax = plt.subplots()
boxplot = sns.boxplot(data=testing_value, palette="PuBuGn_d")
boxplot.set(xlabel='Algorithms', ylabel='RMSE')
sns.set_context("paper", font_scale=2)
sns.set_style("white")
sns.despine(left=True)
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
#training value 
training_value = pd.read_csv("training_value.csv")
training_value = training_value[['SLM (Ensemble)', 'SLM (Ensemble) + RST', 'SLM (Ensemble) + RWT', 'SLM (Ensemble-Bagging)', 
                               'SLM (Ensemble-Bagging) + RST', 'SLM (Ensemble-Bagging) + RWT', 'SLM (Ensemble-RIW)',
                                'SLM (Ensemble-Boosting)', 'SLM (OLS)', 'SLM (OLS) + RST', 'SLM (OLS) + RWT']]
training_value.head(10)
# Out:
#    SLM (Ensemble)  SLM (Ensemble) + RST  SLM (Ensemble) + RWT  \
# 0        0.380521              0.367585              0.383734
# 1        0.389231              0.391454              0.394113
# 2        0.383808              0.392636              0.401302
# 3        0.375095              0.380988              0.378405
# 4        0.372459              0.397489              0.395246
# 5        0.379164              0.377940              0.388501
# 6        0.371515              0.377863              0.389521
# 7        0.363481              0.382075              0.377653
# 8        0.375641              0.377087              0.395096
# 9        0.365583              0.364775              0.394475
#
#    SLM (Ensemble-Bagging)  SLM (Ensemble-Bagging) + RST  \
# 0                0.382338                      0.365798
# 1                0.391278                      0.393580
# 2                0.382960                      0.385509
# 3                0.378397                      0.380915
# 4                0.376088                      0.376652
# 5                0.365978                      0.371062
# 6                0.374744                      0.371852
# 7                0.364746                      0.367581
# 8                0.372789                      0.393765
# 9                0.391593                      0.387304
#
#    SLM (Ensemble-Bagging) + RWT  SLM (Ensemble-RIW)  SLM (Ensemble-Boosting)  \
# 0                      0.378642            0.375939                 0.382762
# 1                      0.395235            0.393530                 0.392114
# 2                      0.400058            0.401657                 0.405754
# 3                      0.380822            0.377287                 0.373964
# 4                      0.390258            0.395532                 0.390838
# 5                      0.387537            0.389948                 0.397215
# 6                      0.383204            0.389306                 0.376344
# 7                      0.384354            0.383841                 0.382007
# 8                      0.394889            0.395694                 0.387290
# 9                      0.393630            0.389009                 0.384203
#
#    SLM (OLS)  SLM (OLS) + RST  SLM (OLS) + RWT
# 0   0.366175         0.382887         0.384755
# 1   0.402071         0.394018         0.396555
# 2   0.394801         0.382437         0.394455
# 3   0.370255         0.371898         0.352930
# 4   0.383811         0.405356         0.394036
# 5   0.399485         0.407364         0.391872
# 6   0.368422         0.368975         0.389367
# 7   0.368922         0.391747         0.387121
# 8   0.391387         0.376808         0.399174
# 9   0.420912         0.426115         0.386280

# %%
fig, ax = plt.subplots()
boxplot = sns.boxplot(data=training_value, palette="PuBuGn_d")
boxplot.set(xlabel='Algorithms', ylabel='RMSE')
sns.set_context("paper", font_scale=2)
sns.set_style("white")
sns.despine(left=True)
boxplot.set_xticklabels(boxplot.get_xticklabels(), rotation=90)
fig.set_size_inches(18.5, 10.5)
plt.show()
