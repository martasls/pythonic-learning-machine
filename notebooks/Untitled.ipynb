# %%
from pmlb import classification_dataset_names, fetch_data

# %%
i = 0
for data_set in classification_dataset_names:
    df = fetch_data(data_set)
    print("Data set name: {}, Data set size: {}".format(data_set, df.shape))
    i+=1
    #print(df.describe())
print("There are {} data sets".format(i))
# Out:
# Data set name: GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1, Data set size: (1600, 1001)
# Data set name: GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1, Data set size: (1600, 21)
# Data set name: GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1, Data set size: (1600, 21)
# Data set name: GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1, Data set size: (1600, 21)
# Data set name: GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001, Data set size: (1600, 21)
# Data set name: GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001, Data set size: (1600, 21)
# Data set name: Hill_Valley_with_noise, Data set size: (1212, 101)
# Data set name: Hill_Valley_without_noise, Data set size: (1212, 101)
# Data set name: adult, Data set size: (48842, 15)
# Data set name: agaricus-lepiota, Data set size: (8145, 23)
# Data set name: allbp, Data set size: (3772, 30)
# Data set name: allhyper, Data set size: (3771, 30)
# Data set name: allhypo, Data set size: (3770, 30)
# Data set name: allrep, Data set size: (3772, 30)
# Data set name: analcatdata_aids, Data set size: (50, 5)
# Data set name: analcatdata_asbestos, Data set size: (83, 4)
# Data set name: analcatdata_authorship, Data set size: (841, 71)
# Data set name: analcatdata_bankruptcy, Data set size: (50, 7)
# Data set name: analcatdata_boxing1, Data set size: (120, 4)
# Data set name: analcatdata_boxing2, Data set size: (132, 4)
# Data set name: analcatdata_creditscore, Data set size: (100, 7)
# Data set name: analcatdata_cyyoung8092, Data set size: (97, 11)
# Data set name: analcatdata_cyyoung9302, Data set size: (92, 11)
# Data set name: analcatdata_dmft, Data set size: (797, 5)
# Data set name: analcatdata_fraud, Data set size: (42, 12)
# Data set name: analcatdata_germangss, Data set size: (400, 6)
# Data set name: analcatdata_happiness, Data set size: (60, 4)
# Data set name: analcatdata_japansolvent, Data set size: (52, 10)
# Data set name: analcatdata_lawsuit, Data set size: (264, 5)
# Data set name: ann-thyroid, Data set size: (7200, 22)
# Data set name: appendicitis, Data set size: (106, 8)
# Data set name: australian, Data set size: (690, 15)
# Data set name: auto, Data set size: (202, 26)
# Data set name: backache, Data set size: (180, 33)
# Data set name: balance-scale, Data set size: (625, 5)
# Data set name: banana, Data set size: (5300, 3)
# Data set name: biomed, Data set size: (209, 9)
# Data set name: breast, Data set size: (699, 11)
# Data set name: breast-cancer, Data set size: (286, 10)
# Data set name: breast-cancer-wisconsin, Data set size: (569, 31)
# Data set name: breast-w, Data set size: (699, 10)
# Data set name: buggyCrx, Data set size: (690, 16)
# Data set name: bupa, Data set size: (345, 7)
# Data set name: calendarDOW, Data set size: (399, 33)
# Data set name: car, Data set size: (1728, 7)
# Data set name: car-evaluation, Data set size: (1728, 22)
# Data set name: cars, Data set size: (392, 9)
# Data set name: cars1, Data set size: (392, 8)
# Data set name: chess, Data set size: (3196, 37)
# Data set name: churn, Data set size: (5000, 21)
# Data set name: clean1, Data set size: (476, 169)
# Data set name: clean2, Data set size: (6598, 169)
# Data set name: cleve, Data set size: (303, 14)
# Data set name: cleveland, Data set size: (303, 14)
# Data set name: cleveland-nominal, Data set size: (303, 8)
# Data set name: cloud, Data set size: (108, 8)
# Data set name: cmc, Data set size: (1473, 10)
# Data set name: coil2000, Data set size: (9822, 86)
# Data set name: colic, Data set size: (368, 23)
# Data set name: collins, Data set size: (485, 24)
# Data set name: confidence, Data set size: (72, 4)
# Data set name: connect-4, Data set size: (67557, 43)
# Data set name: contraceptive, Data set size: (1473, 10)
# Data set name: corral, Data set size: (160, 7)
# Data set name: credit-a, Data set size: (690, 16)
# Data set name: credit-g, Data set size: (1000, 21)
# Data set name: crx, Data set size: (690, 16)
# Data set name: dermatology, Data set size: (366, 35)
# Data set name: diabetes, Data set size: (768, 9)
# Data set name: dis, Data set size: (3772, 30)
# Data set name: dna, Data set size: (3186, 181)
# Data set name: ecoli, Data set size: (327, 8)
# Data set name: fars, Data set size: (100968, 30)
# Data set name: flags, Data set size: (178, 44)
# Data set name: flare, Data set size: (1066, 11)
# Data set name: german, Data set size: (1000, 21)
# Data set name: glass, Data set size: (205, 10)
# Data set name: glass2, Data set size: (163, 10)
# Data set name: haberman, Data set size: (306, 4)
# Data set name: hayes-roth, Data set size: (160, 5)
# Data set name: heart-c, Data set size: (303, 14)
# Data set name: heart-h, Data set size: (294, 14)
# Data set name: heart-statlog, Data set size: (270, 14)
# Data set name: hepatitis, Data set size: (155, 20)
# Data set name: horse-colic, Data set size: (368, 23)
# Data set name: house-votes-84, Data set size: (435, 17)
# Data set name: hungarian, Data set size: (294, 14)
# Data set name: hypothyroid, Data set size: (3163, 26)
# Data set name: ionosphere, Data set size: (351, 35)
# Data set name: iris, Data set size: (150, 5)
# Data set name: irish, Data set size: (500, 6)
# Data set name: kddcup, Data set size: (494020, 42)
# Data set name: kr-vs-kp, Data set size: (3196, 37)
# Data set name: krkopt, Data set size: (28056, 7)
# Data set name: labor, Data set size: (57, 17)
# Data set name: led24, Data set size: (3200, 25)
# Data set name: led7, Data set size: (3200, 8)
# Data set name: letter, Data set size: (20000, 17)
# Data set name: liver-disorder, Data set size: (345, 7)
# Data set name: lupus, Data set size: (87, 4)
# Data set name: lymphography, Data set size: (148, 19)
# Data set name: magic, Data set size: (19020, 11)
# Data set name: mfeat-factors, Data set size: (2000, 217)
# Data set name: mfeat-fourier, Data set size: (2000, 77)
# Data set name: mfeat-karhunen, Data set size: (2000, 65)
# Data set name: mfeat-morphological, Data set size: (2000, 7)
# Data set name: mfeat-pixel, Data set size: (2000, 241)
# Data set name: mfeat-zernike, Data set size: (2000, 48)
# Data set name: mnist, Data set size: (70000, 785)
# Data set name: mofn-3-7-10, Data set size: (1324, 11)
# Data set name: molecular-biology_promoters, Data set size: (106, 59)
# Data set name: monk1, Data set size: (556, 7)
# Data set name: monk2, Data set size: (601, 7)
# Data set name: monk3, Data set size: (554, 7)
# Data set name: movement_libras, Data set size: (360, 91)
# Data set name: mushroom, Data set size: (8124, 23)
# Data set name: mux6, Data set size: (128, 7)
# Data set name: new-thyroid, Data set size: (215, 6)
# Data set name: nursery, Data set size: (12958, 9)
# Data set name: optdigits, Data set size: (5620, 65)
# Data set name: page-blocks, Data set size: (5473, 11)
# Data set name: parity5, Data set size: (32, 6)
# Data set name: parity5+5, Data set size: (1124, 11)
# Data set name: pendigits, Data set size: (10992, 17)
# Data set name: phoneme, Data set size: (5404, 6)
# Data set name: pima, Data set size: (768, 9)
# Data set name: poker, Data set size: (1025009, 11)
# Data set name: postoperative-patient-data, Data set size: (88, 9)
# Data set name: prnn_crabs, Data set size: (200, 8)
# Data set name: prnn_fglass, Data set size: (205, 10)
# Data set name: prnn_synth, Data set size: (250, 3)
# Data set name: profb, Data set size: (672, 10)
# Data set name: promoters, Data set size: (106, 59)
# Data set name: ring, Data set size: (7400, 21)
# Data set name: saheart, Data set size: (462, 10)
# Data set name: satimage, Data set size: (6435, 37)
# Data set name: schizo, Data set size: (340, 15)
# Data set name: segmentation, Data set size: (2310, 20)
# Data set name: shuttle, Data set size: (58000, 10)
# Data set name: sleep, Data set size: (105908, 14)
# Data set name: solar-flare_1, Data set size: (315, 13)
# Data set name: solar-flare_2, Data set size: (1066, 13)
# Data set name: sonar, Data set size: (208, 61)
# Data set name: soybean, Data set size: (675, 36)
# Data set name: spambase, Data set size: (4601, 58)
# Data set name: spect, Data set size: (267, 23)
# Data set name: spectf, Data set size: (349, 45)
# Data set name: splice, Data set size: (3188, 61)
# Data set name: tae, Data set size: (151, 6)
# Data set name: texture, Data set size: (5500, 41)
# Data set name: threeOf9, Data set size: (512, 10)
# Data set name: tic-tac-toe, Data set size: (958, 10)
# Data set name: titanic, Data set size: (2201, 4)
# Data set name: tokyo1, Data set size: (959, 45)
# Data set name: twonorm, Data set size: (7400, 21)
# Data set name: vehicle, Data set size: (846, 19)
# Data set name: vote, Data set size: (435, 17)
# Data set name: vowel, Data set size: (990, 14)
# Data set name: waveform-21, Data set size: (5000, 22)
# Data set name: waveform-40, Data set size: (5000, 41)
# Data set name: wdbc, Data set size: (569, 31)
# Data set name: wine-quality-red, Data set size: (1599, 12)
# Data set name: wine-quality-white, Data set size: (4893, 12)
# Data set name: wine-recognition, Data set size: (178, 14)
# Data set name: xd6, Data set size: (973, 10)
# Data set name: yeast, Data set size: (1479, 9)
# There are 166 data sets

# %%
datasets = {k: {'summary' : None} for k in classification_dataset_names}

# %%
for data_set in classification_dataset_names:
    df = fetch_data(data_set)
    datasets[data_set]['summary'] = get_classification_dataset_summary(df, data_set)

# %%
datasets['adult']['summary']
# Out:
# {'MajorityClassSize': 37155,
#  'MinorityClassSize': 11687,
#  'NumberOfClasses': 2.0,
#  'ImbalanceMetric': 0.27189599079967847,
#  'NumberOfFeatures': 14,
#  'NumberOfBinaryFeatures': 1,
#  'NumberOfIntegerFeatures': 7,
#  'NumberOfFloatFeatures': 6,
#  'NumberOfInstances': 48842,
#  'NumberOfInstancesWithMissingValues': 0,
#  'NumberOfMissingValues': 0,
#  'NumberOfNumericFeatures': 13,
#  'NumberOfSymbolicFeatures': 1,
#  'name': 'adult',
#  'status': 'active'}

# %%
datasets['adult']['summary']['NumberOfClasses'] == 2.0
# Out:
# True

# %%
len(datasets)
# Out:
# 166

# %%
datasets_2classes = {k: v for k, v in datasets.items() if v['summary']['NumberOfClasses'] == 2.0 
                                                      and v['summary']['NumberOfFeatures'] > 20
                                                      and v['summary']['NumberOfInstancesWithMissingValues'] == 0}

# %%
len(datasets_2classes)
# Out:
# 25

# %%
datasets_2classes
# Out:
# {'GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1': {'summary': {'MajorityClassSize': 800,
#    'MinorityClassSize': 800,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0,
#    'NumberOfFeatures': 1000,
#    'NumberOfBinaryFeatures': 31,
#    'NumberOfIntegerFeatures': 969,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 1600,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 969,
#    'NumberOfSymbolicFeatures': 31,
#    'name': 'GAMETES_Epistasis_2-Way_1000atts_0.4H_EDM-1_EDM-1_1',
#    'status': 'active'}},
#  'Hill_Valley_with_noise': {'summary': {'MajorityClassSize': 606,
#    'MinorityClassSize': 606,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0,
#    'NumberOfFeatures': 100,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 100,
#    'NumberOfInstances': 1212,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 100,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'Hill_Valley_with_noise',
#    'status': 'active'}},
#  'Hill_Valley_without_noise': {'summary': {'MajorityClassSize': 612,
#    'MinorityClassSize': 600,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 9.802960494069226e-05,
#    'NumberOfFeatures': 100,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 100,
#    'NumberOfInstances': 1212,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 100,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'Hill_Valley_without_noise',
#    'status': 'active'}},
#  'agaricus-lepiota': {'summary': {'MajorityClassSize': 4228,
#    'MinorityClassSize': 3917,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0014579364729441586,
#    'NumberOfFeatures': 22,
#    'NumberOfBinaryFeatures': 6,
#    'NumberOfIntegerFeatures': 16,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 8145,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 16,
#    'NumberOfSymbolicFeatures': 6,
#    'name': 'agaricus-lepiota',
#    'status': 'active'}},
#  'backache': {'summary': {'MajorityClassSize': 155,
#    'MinorityClassSize': 25,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.521604938271605,
#    'NumberOfFeatures': 32,
#    'NumberOfBinaryFeatures': 22,
#    'NumberOfIntegerFeatures': 4,
#    'NumberOfFloatFeatures': 6,
#    'NumberOfInstances': 180,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 10,
#    'NumberOfSymbolicFeatures': 22,
#    'name': 'backache',
#    'status': 'active'}},
#  'breast-cancer-wisconsin': {'summary': {'MajorityClassSize': 357,
#    'MinorityClassSize': 212,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.06493987849061501,
#    'NumberOfFeatures': 30,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 30,
#    'NumberOfInstances': 569,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 30,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'breast-cancer-wisconsin',
#    'status': 'active'}},
#  'chess': {'summary': {'MajorityClassSize': 1669,
#    'MinorityClassSize': 1527,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.001974072722317166,
#    'NumberOfFeatures': 36,
#    'NumberOfBinaryFeatures': 35,
#    'NumberOfIntegerFeatures': 1,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 3196,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 1,
#    'NumberOfSymbolicFeatures': 35,
#    'name': 'chess',
#    'status': 'active'}},
#  'clean1': {'summary': {'MajorityClassSize': 269,
#    'MinorityClassSize': 207,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.016965609773321087,
#    'NumberOfFeatures': 168,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 2,
#    'NumberOfFloatFeatures': 166,
#    'NumberOfInstances': 476,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 168,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'clean1',
#    'status': 'active'}},
#  'clean2': {'summary': {'MajorityClassSize': 5581,
#    'MinorityClassSize': 1017,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.478483150625434,
#    'NumberOfFeatures': 168,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 2,
#    'NumberOfFloatFeatures': 166,
#    'NumberOfInstances': 6598,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 168,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'clean2',
#    'status': 'active'}},
#  'coil2000': {'summary': {'MajorityClassSize': 9236,
#    'MinorityClassSize': 586,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.7755902757953309,
#    'NumberOfFeatures': 85,
#    'NumberOfBinaryFeatures': 5,
#    'NumberOfIntegerFeatures': 80,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 9822,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 80,
#    'NumberOfSymbolicFeatures': 5,
#    'name': 'coil2000',
#    'status': 'active'}},
#  'colic': {'summary': {'MajorityClassSize': 232,
#    'MinorityClassSize': 136,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0680529300567108,
#    'NumberOfFeatures': 22,
#    'NumberOfBinaryFeatures': 1,
#    'NumberOfIntegerFeatures': 21,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 368,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 21,
#    'NumberOfSymbolicFeatures': 1,
#    'name': 'colic',
#    'status': 'active'}},
#  'dis': {'summary': {'MajorityClassSize': 3714,
#    'MinorityClassSize': 58,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.9394399094067016,
#    'NumberOfFeatures': 29,
#    'NumberOfBinaryFeatures': 21,
#    'NumberOfIntegerFeatures': 8,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 3772,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 8,
#    'NumberOfSymbolicFeatures': 21,
#    'name': 'dis',
#    'status': 'active'}},
#  'horse-colic': {'summary': {'MajorityClassSize': 232,
#    'MinorityClassSize': 136,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0680529300567108,
#    'NumberOfFeatures': 22,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 22,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 368,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 22,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'horse-colic',
#    'status': 'active'}},
#  'hypothyroid': {'summary': {'MajorityClassSize': 3012,
#    'MinorityClassSize': 151,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.8181582834802777,
#    'NumberOfFeatures': 25,
#    'NumberOfBinaryFeatures': 17,
#    'NumberOfIntegerFeatures': 8,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 3163,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 8,
#    'NumberOfSymbolicFeatures': 17,
#    'name': 'hypothyroid',
#    'status': 'active'}},
#  'ionosphere': {'summary': {'MajorityClassSize': 225,
#    'MinorityClassSize': 126,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.07955292570677189,
#    'NumberOfFeatures': 34,
#    'NumberOfBinaryFeatures': 2,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 32,
#    'NumberOfInstances': 351,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 32,
#    'NumberOfSymbolicFeatures': 2,
#    'name': 'ionosphere',
#    'status': 'active'}},
#  'kr-vs-kp': {'summary': {'MajorityClassSize': 1669,
#    'MinorityClassSize': 1527,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.001974072722317166,
#    'NumberOfFeatures': 36,
#    'NumberOfBinaryFeatures': 35,
#    'NumberOfIntegerFeatures': 1,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 3196,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 1,
#    'NumberOfSymbolicFeatures': 35,
#    'name': 'kr-vs-kp',
#    'status': 'active'}},
#  'molecular-biology_promoters': {'summary': {'MajorityClassSize': 53,
#    'MinorityClassSize': 53,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0,
#    'NumberOfFeatures': 58,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 58,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 106,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 58,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'molecular-biology_promoters',
#    'status': 'active'}},
#  'mushroom': {'summary': {'MajorityClassSize': 4208,
#    'MinorityClassSize': 3916,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0012918910021209882,
#    'NumberOfFeatures': 22,
#    'NumberOfBinaryFeatures': 6,
#    'NumberOfIntegerFeatures': 16,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 8124,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 16,
#    'NumberOfSymbolicFeatures': 6,
#    'name': 'mushroom',
#    'status': 'active'}},
#  'promoters': {'summary': {'MajorityClassSize': 53,
#    'MinorityClassSize': 53,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.0,
#    'NumberOfFeatures': 58,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 58,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 106,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 58,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'promoters',
#    'status': 'active'}},
#  'sonar': {'summary': {'MajorityClassSize': 111,
#    'MinorityClassSize': 97,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.00453032544378698,
#    'NumberOfFeatures': 60,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 60,
#    'NumberOfInstances': 208,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 60,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'sonar',
#    'status': 'active'}},
#  'spambase': {'summary': {'MajorityClassSize': 2788,
#    'MinorityClassSize': 1813,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.04490604062004988,
#    'NumberOfFeatures': 57,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 2,
#    'NumberOfFloatFeatures': 55,
#    'NumberOfInstances': 4601,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 57,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'spambase',
#    'status': 'active'}},
#  'spect': {'summary': {'MajorityClassSize': 212,
#    'MinorityClassSize': 55,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.3457616182019667,
#    'NumberOfFeatures': 22,
#    'NumberOfBinaryFeatures': 22,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 0,
#    'NumberOfInstances': 267,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 0,
#    'NumberOfSymbolicFeatures': 22,
#    'name': 'spect',
#    'status': 'active'}},
#  'spectf': {'summary': {'MajorityClassSize': 254,
#    'MinorityClassSize': 95,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.20755987225063832,
#    'NumberOfFeatures': 44,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 44,
#    'NumberOfInstances': 349,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 44,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'spectf',
#    'status': 'active'}},
#  'tokyo1': {'summary': {'MajorityClassSize': 613,
#    'MinorityClassSize': 346,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.07751492093454143,
#    'NumberOfFeatures': 44,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 44,
#    'NumberOfInstances': 959,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 44,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'tokyo1',
#    'status': 'active'}},
#  'wdbc': {'summary': {'MajorityClassSize': 357,
#    'MinorityClassSize': 212,
#    'NumberOfClasses': 2.0,
#    'ImbalanceMetric': 0.06493987849061501,
#    'NumberOfFeatures': 30,
#    'NumberOfBinaryFeatures': 0,
#    'NumberOfIntegerFeatures': 0,
#    'NumberOfFloatFeatures': 30,
#    'NumberOfInstances': 569,
#    'NumberOfInstancesWithMissingValues': 0,
#    'NumberOfMissingValues': 0,
#    'NumberOfNumericFeatures': 30,
#    'NumberOfSymbolicFeatures': 0,
#    'name': 'wdbc',
#    'status': 'active'}}}

# %%
SELECTED_DATASETS = ['Hill_Valley_with_noise', 'Hill_Valley_without_noise', 
                        'agaricus-lepiota', 'backache', 'breast-cancer-wisconsin', 
                        'clean1', 'clean2', 'coil2000', 'dis', 'hypothyroid', 
                        'ionosphere', 'kr-vs-kp', 'molecular-biology_promoters', 
                        'sonar', 'spambase', 'spectf', 'tokyo1', 'credit-g', 
                        'diabetes']

# %%
for data_set in SELECTED_DATASETS:
    print(data_set)
    df = fetch_data(data_set)
# Out:
# Hill_Valley_with_noise
# Hill_Valley_without_noise
# agaricus-lepiota
# backache
# breast-cancer-wisconsin
# clean1
# clean2
# coil2000
# dis
# hypothyroid
# ionosphere
# kr-vs-kp
# molecular-biology_promoters
# sonar
# spambase
# spectf
# tokyo1
# credit-g
# diabetes

# %%
from pmlb.dataset_lists import classification_dataset_names
from pmlb import fetch_data
from pmlb.write_metadata import imbalance_metrics, count_features_type


def compute_class_summary(target):
    class_counts = target.value_counts()
    majority_size, minority_size = class_counts.max(), class_counts.min()
    num_classes, imbalance = imbalance_metrics(target.tolist())
    return majority_size, minority_size, num_classes, imbalance


def compute_missingness_summary(df):
    instances_without_missing = df.dropna(axis=0).shape[0]
    instances_with_missing_values = df.shape[0] - instances_without_missing
    total_missing_values = df.isnull().sum().sum()
    return instances_with_missing_values, total_missing_values


def get_classification_dataset_summary(df, dataset):
    # Class summary
    majority_size, minority_size, num_classes, imbalance = compute_class_summary(df["target"])

    # Feature summary
    num_instances, num_features = df.drop('target', axis=1).shape
    binary_features, integer_features, float_features = count_features_type(df.drop('target', axis=1))
    numeric_features = integer_features + float_features
    symbolic_features = num_features - numeric_features

    # Missing data summary
    instances_with_missing_values, total_missing_values = compute_missingness_summary(df)

    summary = {
        "MajorityClassSize": majority_size,
        "MinorityClassSize": minority_size,
        "NumberOfClasses": num_classes,
        "ImbalanceMetric": imbalance,
        "NumberOfFeatures": num_features,
        "NumberOfBinaryFeatures": binary_features,
        "NumberOfIntegerFeatures": integer_features,
        "NumberOfFloatFeatures": float_features,
        "NumberOfInstances": num_instances,
        "NumberOfInstancesWithMissingValues": instances_with_missing_values,
        "NumberOfMissingValues": total_missing_values,
        "NumberOfNumericFeatures": numeric_features,
        "NumberOfSymbolicFeatures": symbolic_features,
        "name": dataset,
        "status": "active"
    }

    return summary

# %%
get_classification_dataset_summary(df, data_set)
# Out:
# {'MajorityClassSize': 463,
#  'MinorityClassSize': 20,
#  'NumberOfClasses': 9.0,
#  'ImbalanceMetric': 0.1278178474299421,
#  'NumberOfFeatures': 8,
#  'NumberOfBinaryFeatures': 0,
#  'NumberOfIntegerFeatures': 0,
#  'NumberOfFloatFeatures': 8,
#  'NumberOfInstances': 1479,
#  'NumberOfInstancesWithMissingValues': 0,
#  'NumberOfMissingValues': 0,
#  'NumberOfNumericFeatures': 8,
#  'NumberOfSymbolicFeatures': 0,
#  'name': 'yeast',
#  'status': 'active'}
